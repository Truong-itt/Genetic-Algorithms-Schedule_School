# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\hoduy\appdata\local\programs\python\python310\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\hoduy\appdata\local\programs\python\python310\lib\site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the 'c:\Users\hoduy\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
#  # [Genetic Algorithm - GA](https://en.wikipedia.org/wiki/Genetic_algorithm)
#
# Genetic algorithms (GAs) are search and optimization techniques inspired by natural selection and genetics. GAs are used to solve complex problems by simulating biological mechanisms such as mutation, crossover, and selection.
#
# ## 1. Basic Principle
#
# GA works on Charles Darwin's principle of natural selection: **"Better adapted individuals will have more chances to survive and reproduce."**. An optimization problem in GA is usually represented through the following steps:
#
# 1. **Population Initialization**: Create an initial set of individuals (called a population).
# 2. **Evaluation**: Determine the fitness of each individual in the population.
# 3. **Selection**: Select the best individuals based on fitness values ​​to reproduce the next generation.
# 4. **Crossover**: Combine the genetic information of individuals to create new individuals.
# 5. **Mutation**: Randomly change a part of the genetic information of an individual to increase diversity.
# 6. **Iteration**: Repeat the above process until the stopping condition is reached (e.g., reaching the desired number of generations or the optimal value).
#
# ## 2. Components of GA
#
# - **Individual**: A potential solution to the problem.
#
# - **Population**: The set of current individuals.
#
# - **Fitness**: A measure to evaluate the goodness of an individual.
#
# - **Crossover**: A method of combining two parent individuals to create an offspring.
#
# - **Mutation**: Randomly changing a part of the individual's genes to create a difference.
#
# ## 3. Algorithm process
#
# 1. **Initial population**:
# - Randomly generate initial individuals.
#
# 2. **Fitness assessment**:
# - Calculate the fitness value of each individual in the population.
#
# 3. **Selection**:
# - Select the best individuals to form the next generation.
# 4. **Crossover**:
# - Select two parent individuals and combine their genes to create an offspring.
#
# 5. **Mutation**:
# - Randomly change one or more genes of the offspring to increase diversity.
#
# 6. **Population Update**:
# - Replace old individuals with new individuals.
#
# 7. **Stopping Condition Check**:
# - Stop if the condition is met (e.g. maximum number of generations or desired fitness).
#
# ## 4. Applications of GA
#
# - Optimization in many fields such as:
# - Traveling Salesman Problem (TSP).
# - Scheduling.
# - Design Optimization.
# - Machine Learning: Optimizing network parameters and structures.
#
# - Other research problems in biology, finance, and technology.
#
# ## 5. Advantages and disadvantages of GA
#
# ### Advantages:
# - Can solve complex, non-linear problems.
#
# - Search in large spaces with high efficiency.
#
# - Does not require much information about the problem, only needs a fitness function.
#
# ### Disadvantages:
# - Easy to fall into local extremes.
#
# - Long computation time if not optimized.
#
# Need to fine-tune parameters (population size, mutation rate, crossover rate).

# %% [markdown]
# # Implementing GA to solve the timetable problem
#
# ## 1. Timetable representation
# - **Chromosome**: A feasible timetable.
#
# - Gene = (Subject, Teacher, Class, Time, Classroom).
#
# - **Instructor's free time**: Added to check the validity of the gene.
#
# - **Hard** and **Soft** constraints:
# - Hard constraint: Required to comply.
#
# - Soft constraint: Desired, if violated, only fitness points will be reduced.
#
# ## 2. Hard Constraints
# 1. **Teachers do not teach at the same time**:
# - `if Teacher_A teaches at T1 -> Teacher_A does not teach in another class at T1`.
# 2. **Classrooms do not teach at the same time**:
# - `if Room_B is used at T2 -> Room_B is not used by another class at T2`.
# 3. **Subject assigned to the correct teacher**:
#
# - `if Teacher_X is not qualified -> Cannot teach Subject_Y`.
#
# 4. **Each class only studies 1 subject at a time**:
#
# - `if Class_C studies Subject_Z at T3 -> Cannot study other subjects at T3`.
#
# 5. **Maximum number of lessons per day**:
#
# - `if Number of lessons > Limit -> Violation`.
#
# ## 3. Soft Constraints
#
# 1. **Lecturer's free time**:
#
# - `if Time_T is not Teacher_A's free time -> Violation`.
#
# # Simulate the timetable problem space
#
# ## 4. Problem space
# - **3D timetable model**:
# - **X-axis (Day)**: Days of the week (Monday → Saturday).
#
# - **Y-axis (Period)**: Classes of the day (Period 1 → Period 8).
#
# - **Z-axis (Classroom)**: Classrooms (A101, A102, A103...).
#
# ### For example:
# - In the cell `(Saturday, Period 4, Room A101)`:
# - The class card 86 represents the class coded **86**.
#
# This corresponds to: "Saturday, Period 4, in room A101".
#
# ## 5. Overview workflow
# ### **Input**:
# - List of subjects, teachers, classes, classrooms.
# - Lecturer's free time.
# - Hard and soft constraints (predefined).
#
# ### **Workflow**:
# 1. **Spatial modeling**:
# - Create a 3D structure (Day, Period, Room) for the timetable.
#
# 2. **Generate initial population**:
# - Randomly allocate subjects, teachers, classes into cells, obeying hard constraints.
#
# 3. **Optimize**:
# - Repeat optimization steps (GA or other algorithm) to reduce the number of constraint violations and optimize soft constraints.
#
# 4. **Result**:
# - Output the optimal timetable in 3D space.
#
# ## 3. Result
# - The final timetable is represented in 3D space:
#
# - **X-axis**: Day.
#
# - **Y-axis**: Class.
#
# - **Z-axis**: Classroom.
#
# - Each cell contains subject, teacher, and class information.

# %%
import openpyxl
print(openpyxl.__version__)
# Out:
# 3.1.5

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Read excel

# %%
file_path = "ysc_2024.xlsx" 
sheets = pd.read_excel(file_path, sheet_name=None)
dfs = list(sheets.values())

# %%
df_subject = dfs[0]
df_teacher = dfs[1]
df_room = dfs[2]
df_freetime = dfs[3]

# %%
df_teacher.columns = df_teacher.columns.str.strip()

# %%
df_subject.head()
# Out:
#    STT  Mã môn học                       Tên môn học Hình thức  Mã học phần  \
# 0    1        3192             Kỹ năng làm việc nhóm        LT   4203003192
# 1    2        3242  Giáo dục Quốc phòng và An Ninh 1        LT   4203003242
# 2    3        3259                    Toán cao cấp 1        LT   4203003259
# 3    4        3848             Nhập môn Lập trình_TH        TH   4203003848
# 4    5         941                Kỹ thuật lập trình        LT   4203000941
#
#    Số tín chỉ  Số tiết Chuyên ngành
# 0           2        3         KHDL
# 1           4        6         KHDL
# 2           2        6         KHDL
# 3           2        6         KHDL
# 4           3        3         KHDL

# %%
df_teacher.head()
# Out:
#                 Tên Mã môn học  Khoa Chuyên ngành    Title
# 0   Nguyễn Chí Kiên       3192  CNTT         KHDL  Tiến sĩ
# 1  Huỳnh Trung Hiếu       3242  CNTT         KHDL   PGS.TS
# 2     Lê Trọng Ngọc       3259  CNTT         KHDL  Tiến sĩ
# 3   Nguyễn Hữu Tình       2137  CNTT         KHDL  Thạc sĩ
# 4    Bùi Thanh Hùng  3848, 941  CNTT         KHDL  Tiến sĩ

# %%
df_room.head()
# Out:
#   Tên Phòng Hình thức
# 0    A1.01A        LT
# 1    A1.01B        TH
# 2     A1.02        LT
# 3     A1.03        LT
# 4     A1.04        TH

# %%
df_freetime.head()
# Out:
#   Nguyễn Chí Kiên Lê Trọng Ngọc Nguyễn Hữu Tình
# 0           0,  0          2, 2            0, 1
# 1            1, 1          3, 3            2, 0
# 2            3, 2          4, 5            4, 4

# %% [markdown]
# # Data processing conversion

# %% [markdown]
# ### Subjects

# %%
subjects = [
    {
        'Mã môn học': f"{str(row['Mã môn học']).lstrip('0')}_{row['Hình thức']}",
        'Tên môn học': row['Tên môn học'],
        'Hình thức': row['Hình thức'],
        'Số tiết': row['Số tiết']
    }
    for _, row in df_subject.iterrows()
]
subjects
# Out:
# [{'Mã môn học': '3192_LT',
#   'Tên môn học': 'Kỹ năng làm việc nhóm',
#   'Hình thức': 'LT',
#   'Số tiết': 3},
#  {'Mã môn học': '3242_LT',
#   'Tên môn học': 'Giáo dục Quốc phòng và An Ninh 1',
#   'Hình thức': 'LT',
#   'Số tiết': 6},
#  {'Mã môn học': '3259_LT',
#   'Tên môn học': 'Toán cao cấp 1',
#   'Hình thức': 'LT',
#   'Số tiết': 6},
#  {'Mã môn học': '3848_TH',
#   'Tên môn học': 'Nhập môn Lập trình_TH',
#   'Hình thức': 'TH',
#   'Số tiết': 6},
#  {'Mã môn học': '941_LT',
#   'Tên môn học': 'Kỹ thuật lập trình',
#   'Hình thức': 'LT',
#   'Số tiết': 3},
#  {'Mã môn học': '2137_LT',
#   'Tên môn học': 'Hệ thống Máy tính',
#   'Hình thức': 'LT',
#   'Số tiết': 3},
#  {'Mã môn học': '941_TH',
#   'Tên môn học': 'Kỹ thuật lập trình_TH',
#   'Hình thức': 'TH',
#   'Số tiết': 3},
#  {'Mã môn học': '2137_TH',
#   'Tên môn học': 'Hệ thống Máy tính_TH',
#   'Hình thức': 'TH',
#   'Số tiết': 3},
#  {'Mã môn học': '3848_LT',
#   'Tên môn học': 'Nhập môn Lập trình',
#   'Hình thức': 'LT',
#   'Số tiết': 3}]

# %%
for subject in subjects:
    print(subject['Số tiết'])
# Out:
# 3
# 6
# 6
# 6
# 3
# 3
# 3
# 3
# 3

# %% [markdown]
# ### Teachers

# %%
df_teacher['Mã môn học'] = df_teacher['Mã môn học'].astype(str)
df_subject['Mã môn học'] = df_subject['Mã môn học'].astype(str)

# %%
# df_teacher['Mã môn học'], df_subject['Mã môn học'] 
df_teacher_expanded = df_teacher.assign(
    Mã_môn_học_tách=df_teacher['Mã môn học'].str.split(", ")
).explode('Mã_môn_học_tách')

# %%
# Đảm bảo không có giá trị NaN trong cột 'Mã_môn_học_tách'
df_teacher_expanded.dropna(subset=['Mã_môn_học_tách'], inplace=True)

# %%
df_teacher_expanded = df_teacher_expanded.merge(
    df_subject[['Mã môn học', 'Hình thức']].rename(columns={'Mã môn học': 'Mã_môn_học_tách'}),
    on='Mã_môn_học_tách',
    how='left'
)

# %%
df_teacher_expanded['Mã_môn_học_Hình_thức'] = df_teacher_expanded['Mã_môn_học_tách'].str.lstrip("0") + "_" + df_teacher_expanded['Hình thức']

# %%
teacher_subjects = {
    teacher: df_teacher_expanded[df_teacher_expanded['Tên'] == teacher]['Mã_môn_học_Hình_thức'].dropna().tolist()
    for teacher in df_teacher['Tên']
}

# %% [markdown]
# ### Room

# %%
rooms = df_room.to_dict(orient='records')
rooms
# Out:
# [{'Tên Phòng': 'A1.01A', 'Hình thức': 'LT'},
#  {'Tên Phòng': 'A1.01B', 'Hình thức': 'TH'},
#  {'Tên Phòng': 'A1.02', 'Hình thức': 'LT'},
#  {'Tên Phòng': 'A1.03', 'Hình thức': 'LT'},
#  {'Tên Phòng': 'A1.04', 'Hình thức': 'TH'},
#  {'Tên Phòng': 'A1.05', 'Hình thức': 'LT'},
#  {'Tên Phòng': 'A2.01', 'Hình thức': 'TH'},
#  {'Tên Phòng': 'A2.02', 'Hình thức': 'LT'},
#  {'Tên Phòng': 'A2.03', 'Hình thức': 'TH'},
#  {'Tên Phòng': 'A2.04', 'Hình thức': 'TH'}]

# %% [markdown]
# ### Teachers - Freetime

# %%
free_time = {
    col: [tuple(map(int, cell.split(", "))) for cell in df_freetime[col].dropna()]
    for col in df_freetime.columns
}
free_time
# Out:
# {'Nguyễn Chí Kiên': [(0, 0), (1, 1), (3, 2)],
#  'Lê Trọng Ngọc': [(2, 2), (3, 3), (4, 5)],
#  'Nguyễn Hữu Tình': [(0, 1), (2, 0), (4, 4)]}

# %%
NUM_PERIODS = 5   
NUM_DAYS = 7    # Số ngày trong tuần (Thứ 2 - CN)
NUM_WEEKS = 1    
NUM_ROOMS = len(rooms)  
POPULATION_SIZE = 1000
NUM_GENERATIONS = 10000
MUTATION_RATE = 0.1

# %% [markdown]
# # Generate chromosome

# %%
def assign_periods(chromosome, subject, teacher, subject_code, subject_name, subject_form, subject_periods, assigned_days):
    periods_assigned = 0
    attempts = 0

    while periods_assigned < subject_periods and attempts < 300:
        week = random.randint(0, NUM_WEEKS - 1)
        day = random.randint(0, NUM_DAYS - 1)
        period = random.randint(0, NUM_PERIODS - 1)
        room_idx = random.randint(0, NUM_ROOMS - 1)

        room = rooms[room_idx]
        if room['Hình thức'] != subject_form:
            attempts += 1
            continue

        # Kiểm tra số buổi học
        if subject_periods == 6 and len(assigned_days) >= 2 and day not in assigned_days:
            attempts += 1
            continue

        if chromosome[period, day, week, room_idx] is None:
            chromosome[period, day, week, room_idx] = f"{subject_code},{subject_name},{teacher}"
            periods_assigned += 1
            assigned_days.add(day)
            # Nếu đã gán đủ 2 ngày cho môn học có số tiết 6, không cho thêm ngày mới
            if subject_periods == 6 and len(assigned_days) > 2:
                periods_assigned -= 1
                chromosome[period, day, week, room_idx] = None
                attempts += 1
    return periods_assigned, attempts

# %%
def generate_chromosome():
    # Khởi tạo nhiễm sắc thể với cấu trúc 3D (Periods x Days x Weeks x Rooms)
    chromosome = np.full((NUM_PERIODS, NUM_DAYS, NUM_WEEKS, NUM_ROOMS), None, dtype=object)

    for subject in subjects:
        subject_code = str(subject['Mã môn học'])
        subject_name = subject['Tên môn học']
        subject_form = subject['Hình thức']
        subject_periods = subject['Số tiết']
        teacher_candidates = [t for t, subjs in teacher_subjects.items() if subject_code in subjs]

        if not teacher_candidates:
            continue

        teacher = random.choice(teacher_candidates)
        assigned_days = set()

        # gán buổi học
        periods_assigned, attempts = assign_periods(
            chromosome, subject, teacher, subject_code, subject_name, subject_form, subject_periods, assigned_days
        )
    return chromosome

# %% [markdown]
# # Fitness

# %%
def calculate_teacher_violations(chromosome, period, day, week, teacher_set, room_idx, entry):
    violations = 0
    subject_code, subject_name, teacher = entry.split(',')
    # gian vien khong day hai mon cung mot thoi diem
    if teacher in teacher_set:
        violations += 10
    teacher_set.add(teacher)
    return violations, teacher_set

# %%
def check_room_form_violations(entry, room):
    violations = 0
    subject_code, subject_name, teacher = entry.split(',')
    subject_form = [s['Hình thức'] for s in subjects if str(s['Mã môn học']) == subject_code][0]

    # Kiểm tra hình thức phòng học
    if room['Hình thức'] != subject_form:
        violations += 5
    return violations

# %%
def update_subject_periods(entry, subject_count, subject_periods, period, day):
    subject_code, subject_name, teacher = entry.split(',')

    # Đếm số lần môn học được dạy
    if subject_code in subject_count:
        subject_count[subject_code] += 1
        # Lưu ca học
        subject_periods[subject_code].add((period, day)) 
    else:
        subject_count[subject_code] = 1
        subject_periods[subject_code] = {(period, day)}

    return subject_count, subject_periods

# %%
def calculate_schedule_violations(subject_count, subject_periods):
    violations = 0

    # mỗi môn học có ít nhất một buổi
    # Phạt nặng nếu môn không được dạy
    for subject_code, count in subject_count.items():
        if count < 1:
            violations += 20  

    # Kiểm tra trên số ca học
    for subject in subjects:
        subject_code = str(subject['Mã môn học'])
        num_periods = len(subject_periods[subject_code])

        # Phạt nặng môn học 6 tiết > 2 ca
        if subject['Số tiết'] == 6 and num_periods > 2:
            # pha tren moi ca
            violations += 30 * (num_periods - 2)

        # Phạt nặng môn học 3 tiết > 1 ca
        if subject['Số tiết'] == 3 and num_periods > 1:
            # pha tren moi ca
            violations += 30 * (num_periods - 1)  
    return violations

# %%
def fitness(chromosome):
    violations = 0
    # Đảm bảo tất cả mã môn học được chuyển thành chuỗi
    subject_count = {str(subject['Mã môn học']): 0 for subject in subjects}  # Đếm số buổi học cho từng môn
    subject_periods = {str(subject['Mã môn học']): set() for subject in subjects}  # Theo dõi số ca học của từng môn

    for week in range(NUM_WEEKS):
        for day in range(NUM_DAYS):
            for period in range(NUM_PERIODS):
                teacher_set = set()

                for room_idx in range(NUM_ROOMS):
                    entry = chromosome[period, day, week, room_idx]
                    if entry:
                        # Tính vi phạm đến giáo viên
                        teacher_violations, teacher_set = calculate_teacher_violations(
                            chromosome, period, day, week, teacher_set, room_idx, entry
                        )
                        violations += teacher_violations

                        # Tính vi phạm hình thức phòng học
                        room = rooms[room_idx]
                        violations += check_room_form_violations(entry, room)

                        # Cập nhật thông tin về số lần dạy và ca học
                        subject_count, subject_periods = update_subject_periods(
                            entry, subject_count, subject_periods, period, day
                        )

    # Tính vi phạm
    violations += calculate_schedule_violations(subject_count, subject_periods)
    return 1 / (1 + violations)

# %% [markdown]
# # Chooose parents crossover

# %%
def select_parents(population):
    # chon nua ca the toi nhat tu featness
    return sorted(population, key=lambda x: fitness(x), reverse=True)[:POPULATION_SIZE // 2]

# %% [markdown]
# # Crossover

# %%
# lai ghep
def crossover(parent1, parent2):
    child = parent1.copy()
    for period in range(NUM_PERIODS):
        for day in range(NUM_DAYS):
            for week in range(NUM_WEEKS):
                if random.random() < 0.5:
                    child[period, day, week] = parent2[period, day, week]
    return child

# %% [markdown]
# # Mutate

# %%
# dot bien
def mutate(child, mutation_rate):
    if random.random() < mutation_rate:
        period = random.randint(0, NUM_PERIODS - 1)
        day = random.randint(0, NUM_DAYS - 1)
        week = random.randint(0, NUM_WEEKS - 1)
        room_idx = random.randint(0, NUM_ROOMS - 1)
        subject = random.choice(subjects)
        subject_code = str(subject['Mã môn học'])
        subject_name = subject['Tên môn học']
        teacher_candidates = [t for t, subjs in teacher_subjects.items() if subject_code in subjs]
        if teacher_candidates:
            teacher = random.choice(teacher_candidates)
            room = rooms[room_idx]
            if room['Hình thức'] == subject['Hình thức']:
                child[period, day, week, room_idx] = f"{subject_code},{subject_name},{teacher}"

# %% [markdown]
# # Performance evaluation

# %%
def track_progress(current_best_fitness, best_fitness, stagnant_generations):
    if current_best_fitness > best_fitness:
        # Reset số thế hệ không cải tiến
        return current_best_fitness, 0  
    else:
        return best_fitness, stagnant_generations + 1

# %% [markdown]
# # Evolve

# %%
def evolve_population(population, num_generations, mutation_rate):
    # Fitness tốt nhất ban đầu
    best_fitness = 0  
    # Đếm số thế hệ không cải tiến
    stagnant_generations = 0  
    MAX_STAGNANT_GENERATIONS = 500

    for generation in range(num_generations):
        # Chọn lọc
        new_population = select_parents(population)

        # Lai ghép và đột biến 
        while len(new_population) < POPULATION_SIZE:
            parent1, parent2 = random.choices(new_population, k=2)
            child = crossover(parent1, parent2)
            mutate(child, mutation_rate)
            new_population.append(child)

        # Cập nhật 
        population = new_population

        # theo doi 
        current_best_fitness = fitness(population[0])
        best_fitness, stagnant_generations = track_progress(current_best_fitness, best_fitness, stagnant_generations)
        print(f"Generation {generation + 1}: Best Fitness = {current_best_fitness}")

        # Dừng khi ko cai thien
        if stagnant_generations >= MAX_STAGNANT_GENERATIONS:
            print(f"No improvement in {MAX_STAGNANT_GENERATIONS} generations. Stopping early.")
            break
    return max(population, key=fitness)

# %% [markdown]
# # Run

# %%
# khoi tao
population = [generate_chromosome() for _ in range(POPULATION_SIZE)]

# %%
#  tien hoa
best_schedule = evolve_population(population, NUM_GENERATIONS, MUTATION_RATE)
# Out:
# Generation 1: Best Fitness = 0.0018832391713747645
# Generation 2: Best Fitness = 0.0035587188612099642
# Generation 3: Best Fitness = 0.0035587188612099642
# Generation 4: Best Fitness = 0.0038314176245210726
# Generation 5: Best Fitness = 0.005235602094240838
# Generation 6: Best Fitness = 0.007633587786259542
# Generation 7: Best Fitness = 0.012345679012345678
# Generation 8: Best Fitness = 0.012345679012345678
# Generation 9: Best Fitness = 0.01639344262295082
# Generation 10: Best Fitness = 0.01639344262295082
# Generation 11: Best Fitness = 0.03225806451612903
# Generation 12: Best Fitness = 0.03225806451612903
# Generation 13: Best Fitness = 0.047619047619047616
# Generation 14: Best Fitness = 0.047619047619047616
# Generation 15: Best Fitness = 0.047619047619047616
# Generation 16: Best Fitness = 1.0
# Generation 17: Best Fitness = 1.0
# Generation 18: Best Fitness = 1.0
# Generation 19: Best Fitness = 1.0
# Generation 20: Best Fitness = 1.0
# Generation 21: Best Fitness = 1.0
# Generation 22: Best Fitness = 1.0
# Generation 23: Best Fitness = 1.0
# Generation 24: Best Fitness = 1.0
# Generation 25: Best Fitness = 1.0
# Generation 26: Best Fitness = 1.0
# Generation 27: Best Fitness = 1.0
# Generation 28: Best Fitness = 1.0
# Generation 29: Best Fitness = 1.0
# Generation 30: Best Fitness = 1.0
# Generation 31: Best Fitness = 1.0
# Generation 32: Best Fitness = 1.0
# Generation 33: Best Fitness = 1.0
# Generation 34: Best Fitness = 1.0
# Generation 35: Best Fitness = 1.0
# Generation 36: Best Fitness = 1.0
# Generation 37: Best Fitness = 1.0
# Generation 38: Best Fitness = 1.0
# Generation 39: Best Fitness = 1.0
# Generation 40: Best Fitness = 1.0
# Generation 41: Best Fitness = 1.0
# Generation 42: Best Fitness = 1.0
# Generation 43: Best Fitness = 1.0
# Generation 44: Best Fitness = 1.0
# Generation 45: Best Fitness = 1.0
# Generation 46: Best Fitness = 1.0
# Generation 47: Best Fitness = 1.0
# Generation 48: Best Fitness = 1.0
# Generation 49: Best Fitness = 1.0
# Generation 50: Best Fitness = 1.0
# Generation 51: Best Fitness = 1.0
# Generation 52: Best Fitness = 1.0
# Generation 53: Best Fitness = 1.0
# Generation 54: Best Fitness = 1.0
# Generation 55: Best Fitness = 1.0
# Generation 56: Best Fitness = 1.0
# Generation 57: Best Fitness = 1.0
# Generation 58: Best Fitness = 1.0
# Generation 59: Best Fitness = 1.0
# Generation 60: Best Fitness = 1.0
# Generation 61: Best Fitness = 1.0
# Generation 62: Best Fitness = 1.0
# Generation 63: Best Fitness = 1.0
# Generation 64: Best Fitness = 1.0
# Generation 65: Best Fitness = 1.0
# Generation 66: Best Fitness = 1.0
# Generation 67: Best Fitness = 1.0
# Generation 68: Best Fitness = 1.0
# Generation 69: Best Fitness = 1.0
# Generation 70: Best Fitness = 1.0
# Generation 71: Best Fitness = 1.0
# Generation 72: Best Fitness = 1.0
# Generation 73: Best Fitness = 1.0
# Generation 74: Best Fitness = 1.0
# Generation 75: Best Fitness = 1.0
# Generation 76: Best Fitness = 1.0
# Generation 77: Best Fitness = 1.0
# Generation 78: Best Fitness = 1.0
# Generation 79: Best Fitness = 1.0
# Generation 80: Best Fitness = 1.0
# Generation 81: Best Fitness = 1.0
# Generation 82: Best Fitness = 1.0
# Generation 83: Best Fitness = 1.0
# Generation 84: Best Fitness = 1.0
# Generation 85: Best Fitness = 1.0
# Generation 86: Best Fitness = 1.0
# Generation 87: Best Fitness = 1.0
# Generation 88: Best Fitness = 1.0
# Generation 89: Best Fitness = 1.0
# Generation 90: Best Fitness = 1.0
# Generation 91: Best Fitness = 1.0
# Generation 92: Best Fitness = 1.0
# Generation 93: Best Fitness = 1.0
# Generation 94: Best Fitness = 1.0
# Generation 95: Best Fitness = 1.0
# Generation 96: Best Fitness = 1.0
# Generation 97: Best Fitness = 1.0
# Generation 98: Best Fitness = 1.0
# Generation 99: Best Fitness = 1.0
# Generation 100: Best Fitness = 1.0
# Generation 101: Best Fitness = 1.0
# Generation 102: Best Fitness = 1.0
# Generation 103: Best Fitness = 1.0
# Generation 104: Best Fitness = 1.0
# Generation 105: Best Fitness = 1.0
# Generation 106: Best Fitness = 1.0
# Generation 107: Best Fitness = 1.0
# Generation 108: Best Fitness = 1.0
# Generation 109: Best Fitness = 1.0
# Generation 110: Best Fitness = 1.0
# Generation 111: Best Fitness = 1.0
# Generation 112: Best Fitness = 1.0
# Generation 113: Best Fitness = 1.0
# Generation 114: Best Fitness = 1.0
# Generation 115: Best Fitness = 1.0
# Generation 116: Best Fitness = 1.0
# Generation 117: Best Fitness = 1.0
# Generation 118: Best Fitness = 1.0
# Generation 119: Best Fitness = 1.0
# Generation 120: Best Fitness = 1.0
# Generation 121: Best Fitness = 1.0
# Generation 122: Best Fitness = 1.0
# Generation 123: Best Fitness = 1.0
# Generation 124: Best Fitness = 1.0
# Generation 125: Best Fitness = 1.0
# Generation 126: Best Fitness = 1.0
# Generation 127: Best Fitness = 1.0
# Generation 128: Best Fitness = 1.0
# Generation 129: Best Fitness = 1.0
# Generation 130: Best Fitness = 1.0
# Generation 131: Best Fitness = 1.0
# Generation 132: Best Fitness = 1.0
# Generation 133: Best Fitness = 1.0
# Generation 134: Best Fitness = 1.0
# Generation 135: Best Fitness = 1.0
# Generation 136: Best Fitness = 1.0
# Generation 137: Best Fitness = 1.0
# Generation 138: Best Fitness = 1.0
# Generation 139: Best Fitness = 1.0
# Generation 140: Best Fitness = 1.0
# Generation 141: Best Fitness = 1.0
# Generation 142: Best Fitness = 1.0
# Generation 143: Best Fitness = 1.0
# Generation 144: Best Fitness = 1.0
# Generation 145: Best Fitness = 1.0
# Generation 146: Best Fitness = 1.0
# Generation 147: Best Fitness = 1.0
# Generation 148: Best Fitness = 1.0
# Generation 149: Best Fitness = 1.0
# Generation 150: Best Fitness = 1.0
# Generation 151: Best Fitness = 1.0
# Generation 152: Best Fitness = 1.0
# Generation 153: Best Fitness = 1.0
# Generation 154: Best Fitness = 1.0
# Generation 155: Best Fitness = 1.0
# Generation 156: Best Fitness = 1.0
# Generation 157: Best Fitness = 1.0
# Generation 158: Best Fitness = 1.0
# Generation 159: Best Fitness = 1.0
# Generation 160: Best Fitness = 1.0
# Generation 161: Best Fitness = 1.0
# Generation 162: Best Fitness = 1.0
# Generation 163: Best Fitness = 1.0
# Generation 164: Best Fitness = 1.0
# Generation 165: Best Fitness = 1.0
# Generation 166: Best Fitness = 1.0
# Generation 167: Best Fitness = 1.0
# Generation 168: Best Fitness = 1.0
# Generation 169: Best Fitness = 1.0
# Generation 170: Best Fitness = 1.0
# Generation 171: Best Fitness = 1.0
# Generation 172: Best Fitness = 1.0
# Generation 173: Best Fitness = 1.0
# Generation 174: Best Fitness = 1.0
# Generation 175: Best Fitness = 1.0
# Generation 176: Best Fitness = 1.0
# Generation 177: Best Fitness = 1.0
# Generation 178: Best Fitness = 1.0
# Generation 179: Best Fitness = 1.0
# Generation 180: Best Fitness = 1.0
# Generation 181: Best Fitness = 1.0
# Generation 182: Best Fitness = 1.0
# Generation 183: Best Fitness = 1.0
# Generation 184: Best Fitness = 1.0
# Generation 185: Best Fitness = 1.0
# Generation 186: Best Fitness = 1.0
# Generation 187: Best Fitness = 1.0
# Generation 188: Best Fitness = 1.0
# Generation 189: Best Fitness = 1.0
# Generation 190: Best Fitness = 1.0
# Generation 191: Best Fitness = 1.0
# Generation 192: Best Fitness = 1.0
# Generation 193: Best Fitness = 1.0
# Generation 194: Best Fitness = 1.0
# Generation 195: Best Fitness = 1.0
# Generation 196: Best Fitness = 1.0
# Generation 197: Best Fitness = 1.0
# Generation 198: Best Fitness = 1.0
# Generation 199: Best Fitness = 1.0
# Generation 200: Best Fitness = 1.0
# Generation 201: Best Fitness = 1.0
# Generation 202: Best Fitness = 1.0
# Generation 203: Best Fitness = 1.0
# Generation 204: Best Fitness = 1.0
# Generation 205: Best Fitness = 1.0
# Generation 206: Best Fitness = 1.0
# Generation 207: Best Fitness = 1.0
# Generation 208: Best Fitness = 1.0
# Generation 209: Best Fitness = 1.0
# Generation 210: Best Fitness = 1.0
# Generation 211: Best Fitness = 1.0
# Generation 212: Best Fitness = 1.0
# Generation 213: Best Fitness = 1.0
# Generation 214: Best Fitness = 1.0
# Generation 215: Best Fitness = 1.0
# Generation 216: Best Fitness = 1.0
# Generation 217: Best Fitness = 1.0
# Generation 218: Best Fitness = 1.0
# Generation 219: Best Fitness = 1.0
# Generation 220: Best Fitness = 1.0
# Generation 221: Best Fitness = 1.0
# Generation 222: Best Fitness = 1.0
# Generation 223: Best Fitness = 1.0
# Generation 224: Best Fitness = 1.0
# Generation 225: Best Fitness = 1.0
# Generation 226: Best Fitness = 1.0
# Generation 227: Best Fitness = 1.0
# Generation 228: Best Fitness = 1.0
# Generation 229: Best Fitness = 1.0
# Generation 230: Best Fitness = 1.0
# Generation 231: Best Fitness = 1.0
# Generation 232: Best Fitness = 1.0
# Generation 233: Best Fitness = 1.0
# Generation 234: Best Fitness = 1.0
# Generation 235: Best Fitness = 1.0
# Generation 236: Best Fitness = 1.0
# Generation 237: Best Fitness = 1.0
# Generation 238: Best Fitness = 1.0
# Generation 239: Best Fitness = 1.0
# Generation 240: Best Fitness = 1.0
# Generation 241: Best Fitness = 1.0
# Generation 242: Best Fitness = 1.0
# Generation 243: Best Fitness = 1.0
# Generation 244: Best Fitness = 1.0
# Generation 245: Best Fitness = 1.0
# Generation 246: Best Fitness = 1.0
# Generation 247: Best Fitness = 1.0
# Generation 248: Best Fitness = 1.0
# Generation 249: Best Fitness = 1.0
# Generation 250: Best Fitness = 1.0
# Generation 251: Best Fitness = 1.0
# Generation 252: Best Fitness = 1.0
# Generation 253: Best Fitness = 1.0
# Generation 254: Best Fitness = 1.0
# Generation 255: Best Fitness = 1.0
# Generation 256: Best Fitness = 1.0
# Generation 257: Best Fitness = 1.0
# Generation 258: Best Fitness = 1.0
# Generation 259: Best Fitness = 1.0
# Generation 260: Best Fitness = 1.0
# Generation 261: Best Fitness = 1.0
# Generation 262: Best Fitness = 1.0
# Generation 263: Best Fitness = 1.0
# Generation 264: Best Fitness = 1.0
# Generation 265: Best Fitness = 1.0
# Generation 266: Best Fitness = 1.0
# Generation 267: Best Fitness = 1.0
# Generation 268: Best Fitness = 1.0
# Generation 269: Best Fitness = 1.0
# Generation 270: Best Fitness = 1.0
# Generation 271: Best Fitness = 1.0
# Generation 272: Best Fitness = 1.0
# Generation 273: Best Fitness = 1.0
# Generation 274: Best Fitness = 1.0
# Generation 275: Best Fitness = 1.0
# Generation 276: Best Fitness = 1.0
# Generation 277: Best Fitness = 1.0
# Generation 278: Best Fitness = 1.0
# Generation 279: Best Fitness = 1.0
# Generation 280: Best Fitness = 1.0
# Generation 281: Best Fitness = 1.0
# Generation 282: Best Fitness = 1.0
# Generation 283: Best Fitness = 1.0
# Generation 284: Best Fitness = 1.0
# Generation 285: Best Fitness = 1.0
# Generation 286: Best Fitness = 1.0
# Generation 287: Best Fitness = 1.0
# Generation 288: Best Fitness = 1.0
# Generation 289: Best Fitness = 1.0
# Generation 290: Best Fitness = 1.0
# Generation 291: Best Fitness = 1.0
# Generation 292: Best Fitness = 1.0
# Generation 293: Best Fitness = 1.0
# Generation 294: Best Fitness = 1.0
# Generation 295: Best Fitness = 1.0
# Generation 296: Best Fitness = 1.0
# Generation 297: Best Fitness = 1.0
# Generation 298: Best Fitness = 1.0
# Generation 299: Best Fitness = 1.0
# Generation 300: Best Fitness = 1.0
# Generation 301: Best Fitness = 1.0
# Generation 302: Best Fitness = 1.0
# Generation 303: Best Fitness = 1.0
# Generation 304: Best Fitness = 1.0
# Generation 305: Best Fitness = 1.0
# Generation 306: Best Fitness = 1.0
# Generation 307: Best Fitness = 1.0
# Generation 308: Best Fitness = 1.0
# Generation 309: Best Fitness = 1.0
# Generation 310: Best Fitness = 1.0
# Generation 311: Best Fitness = 1.0
# Generation 312: Best Fitness = 1.0
# Generation 313: Best Fitness = 1.0
# Generation 314: Best Fitness = 1.0
# Generation 315: Best Fitness = 1.0
# Generation 316: Best Fitness = 1.0
# Generation 317: Best Fitness = 1.0
# Generation 318: Best Fitness = 1.0
# Generation 319: Best Fitness = 1.0
# Generation 320: Best Fitness = 1.0
# Generation 321: Best Fitness = 1.0
# Generation 322: Best Fitness = 1.0
# Generation 323: Best Fitness = 1.0
# Generation 324: Best Fitness = 1.0
# Generation 325: Best Fitness = 1.0
# Generation 326: Best Fitness = 1.0
# Generation 327: Best Fitness = 1.0
# Generation 328: Best Fitness = 1.0
# Generation 329: Best Fitness = 1.0
# Generation 330: Best Fitness = 1.0
# Generation 331: Best Fitness = 1.0
# Generation 332: Best Fitness = 1.0
# Generation 333: Best Fitness = 1.0
# Generation 334: Best Fitness = 1.0
# Generation 335: Best Fitness = 1.0
# Generation 336: Best Fitness = 1.0
# Generation 337: Best Fitness = 1.0
# Generation 338: Best Fitness = 1.0
# Generation 339: Best Fitness = 1.0
# Generation 340: Best Fitness = 1.0
# Generation 341: Best Fitness = 1.0
# Generation 342: Best Fitness = 1.0
# Generation 343: Best Fitness = 1.0
# Generation 344: Best Fitness = 1.0
# Generation 345: Best Fitness = 1.0
# Generation 346: Best Fitness = 1.0
# Generation 347: Best Fitness = 1.0
# Generation 348: Best Fitness = 1.0
# Generation 349: Best Fitness = 1.0
# Generation 350: Best Fitness = 1.0
# Generation 351: Best Fitness = 1.0
# Generation 352: Best Fitness = 1.0
# Generation 353: Best Fitness = 1.0
# Generation 354: Best Fitness = 1.0
# Generation 355: Best Fitness = 1.0
# Generation 356: Best Fitness = 1.0
# Generation 357: Best Fitness = 1.0
# Generation 358: Best Fitness = 1.0
# Generation 359: Best Fitness = 1.0
# Generation 360: Best Fitness = 1.0
# Generation 361: Best Fitness = 1.0
# Generation 362: Best Fitness = 1.0
# Generation 363: Best Fitness = 1.0
# Generation 364: Best Fitness = 1.0
# Generation 365: Best Fitness = 1.0
# Generation 366: Best Fitness = 1.0
# Generation 367: Best Fitness = 1.0
# Generation 368: Best Fitness = 1.0
# Generation 369: Best Fitness = 1.0
# Generation 370: Best Fitness = 1.0
# Generation 371: Best Fitness = 1.0
# Generation 372: Best Fitness = 1.0
# Generation 373: Best Fitness = 1.0
# Generation 374: Best Fitness = 1.0
# Generation 375: Best Fitness = 1.0
# Generation 376: Best Fitness = 1.0
# Generation 377: Best Fitness = 1.0
# Generation 378: Best Fitness = 1.0
# Generation 379: Best Fitness = 1.0
# Generation 380: Best Fitness = 1.0
# Generation 381: Best Fitness = 1.0
# Generation 382: Best Fitness = 1.0
# Generation 383: Best Fitness = 1.0
# Generation 384: Best Fitness = 1.0
# Generation 385: Best Fitness = 1.0
# Generation 386: Best Fitness = 1.0
# Generation 387: Best Fitness = 1.0
# Generation 388: Best Fitness = 1.0
# Generation 389: Best Fitness = 1.0
# Generation 390: Best Fitness = 1.0
# Generation 391: Best Fitness = 1.0
# Generation 392: Best Fitness = 1.0
# Generation 393: Best Fitness = 1.0
# Generation 394: Best Fitness = 1.0
# Generation 395: Best Fitness = 1.0
# Generation 396: Best Fitness = 1.0
# Generation 397: Best Fitness = 1.0
# Generation 398: Best Fitness = 1.0
# Generation 399: Best Fitness = 1.0
# Generation 400: Best Fitness = 1.0
# Generation 401: Best Fitness = 1.0
# Generation 402: Best Fitness = 1.0
# Generation 403: Best Fitness = 1.0
# Generation 404: Best Fitness = 1.0
# Generation 405: Best Fitness = 1.0
# Generation 406: Best Fitness = 1.0
# Generation 407: Best Fitness = 1.0
# Generation 408: Best Fitness = 1.0
# Generation 409: Best Fitness = 1.0
# Generation 410: Best Fitness = 1.0
# Generation 411: Best Fitness = 1.0
# Generation 412: Best Fitness = 1.0
# Generation 413: Best Fitness = 1.0
# Generation 414: Best Fitness = 1.0
# Generation 415: Best Fitness = 1.0
# Generation 416: Best Fitness = 1.0
# Generation 417: Best Fitness = 1.0
# Generation 418: Best Fitness = 1.0
# Generation 419: Best Fitness = 1.0
# Generation 420: Best Fitness = 1.0
# Generation 421: Best Fitness = 1.0
# Generation 422: Best Fitness = 1.0
# Generation 423: Best Fitness = 1.0
# Generation 424: Best Fitness = 1.0
# Generation 425: Best Fitness = 1.0
# Generation 426: Best Fitness = 1.0
# Generation 427: Best Fitness = 1.0
# Generation 428: Best Fitness = 1.0
# Generation 429: Best Fitness = 1.0
# Generation 430: Best Fitness = 1.0
# Generation 431: Best Fitness = 1.0
# Generation 432: Best Fitness = 1.0
# Generation 433: Best Fitness = 1.0
# Generation 434: Best Fitness = 1.0
# Generation 435: Best Fitness = 1.0
# Generation 436: Best Fitness = 1.0
# Generation 437: Best Fitness = 1.0
# Generation 438: Best Fitness = 1.0
# Generation 439: Best Fitness = 1.0
# Generation 440: Best Fitness = 1.0
# Generation 441: Best Fitness = 1.0
# Generation 442: Best Fitness = 1.0
# Generation 443: Best Fitness = 1.0
# Generation 444: Best Fitness = 1.0
# Generation 445: Best Fitness = 1.0
# Generation 446: Best Fitness = 1.0
# Generation 447: Best Fitness = 1.0
# Generation 448: Best Fitness = 1.0
# Generation 449: Best Fitness = 1.0
# Generation 450: Best Fitness = 1.0
# Generation 451: Best Fitness = 1.0
# Generation 452: Best Fitness = 1.0
# Generation 453: Best Fitness = 1.0
# Generation 454: Best Fitness = 1.0
# Generation 455: Best Fitness = 1.0
# Generation 456: Best Fitness = 1.0
# Generation 457: Best Fitness = 1.0
# Generation 458: Best Fitness = 1.0
# Generation 459: Best Fitness = 1.0
# Generation 460: Best Fitness = 1.0
# Generation 461: Best Fitness = 1.0
# Generation 462: Best Fitness = 1.0
# Generation 463: Best Fitness = 1.0
# Generation 464: Best Fitness = 1.0
# Generation 465: Best Fitness = 1.0
# Generation 466: Best Fitness = 1.0
# Generation 467: Best Fitness = 1.0
# Generation 468: Best Fitness = 1.0
# Generation 469: Best Fitness = 1.0
# Generation 470: Best Fitness = 1.0
# Generation 471: Best Fitness = 1.0
# Generation 472: Best Fitness = 1.0
# Generation 473: Best Fitness = 1.0
# Generation 474: Best Fitness = 1.0
# Generation 475: Best Fitness = 1.0
# Generation 476: Best Fitness = 1.0
# Generation 477: Best Fitness = 1.0
# Generation 478: Best Fitness = 1.0
# Generation 479: Best Fitness = 1.0
# Generation 480: Best Fitness = 1.0
# Generation 481: Best Fitness = 1.0
# Generation 482: Best Fitness = 1.0
# Generation 483: Best Fitness = 1.0
# Generation 484: Best Fitness = 1.0
# Generation 485: Best Fitness = 1.0
# Generation 486: Best Fitness = 1.0
# Generation 487: Best Fitness = 1.0
# Generation 488: Best Fitness = 1.0
# Generation 489: Best Fitness = 1.0
# Generation 490: Best Fitness = 1.0
# Generation 491: Best Fitness = 1.0
# Generation 492: Best Fitness = 1.0
# Generation 493: Best Fitness = 1.0
# Generation 494: Best Fitness = 1.0
# Generation 495: Best Fitness = 1.0
# Generation 496: Best Fitness = 1.0
# Generation 497: Best Fitness = 1.0
# Generation 498: Best Fitness = 1.0
# Generation 499: Best Fitness = 1.0
# Generation 500: Best Fitness = 1.0
# Generation 501: Best Fitness = 1.0
# Generation 502: Best Fitness = 1.0
# Generation 503: Best Fitness = 1.0
# Generation 504: Best Fitness = 1.0
# Generation 505: Best Fitness = 1.0
# Generation 506: Best Fitness = 1.0
# Generation 507: Best Fitness = 1.0
# Generation 508: Best Fitness = 1.0
# Generation 509: Best Fitness = 1.0
# Generation 510: Best Fitness = 1.0
# Generation 511: Best Fitness = 1.0
# Generation 512: Best Fitness = 1.0
# Generation 513: Best Fitness = 1.0
# Generation 514: Best Fitness = 1.0
# Generation 515: Best Fitness = 1.0
# Generation 516: Best Fitness = 1.0
# No improvement in 500 generations. Stopping early.

# %% [markdown]
# # Take the population with the best results

# %%
# trich xuat
schedule_data = []
for week in range(NUM_WEEKS):
    for day in range(NUM_DAYS):
        for period in range(NUM_PERIODS):
            for room_idx in range(NUM_ROOMS):
                entry = best_schedule[period, day, week, room_idx]
                if entry:
                    subject_code, subject_name, teacher = entry.split(',')
                    schedule_data.append({
                        "Week": week + 1,
                        "Day": day + 2,
                        "Period": period + 1,
                        "Room": rooms[room_idx]['Tên Phòng'],
                        "Subject": subject_name.strip(),
                        "Teacher": teacher.strip()
                    })

# %%
# Tao df
df_schedule = pd.DataFrame(schedule_data)
print(df_schedule.head())
# Out:
#    Week  Day  Period    Room                           Subject  \
# 0     1    2       1  A1.01A                 Hệ thống Máy tính
# 1     1    2       3   A1.03             Kỹ năng làm việc nhóm
# 2     1    2       3   A2.02                Nhập môn Lập trình
# 3     1    2       5   A1.03  Giáo dục Quốc phòng và An Ninh 1
# 4     1    2       5   A2.01             Nhập môn Lập trình_TH
#
#             Teacher
# 0   Nguyễn Hữu Tình
# 1   Nguyễn Chí Kiên
# 2    Bùi Thanh Hùng
# 3  Huỳnh Trung Hiếu
# 4    Bùi Thanh Hùng

# %% [markdown]
# # Store the results after processing

# %%
# Xuất ra file Excel
df_schedule.to_excel("optimal_schedule.xlsx", index=False)
print("Lịch trình đã được lưu vào file 'optimal_schedule.xlsx'.")
# Out:
# Lịch trình đã được lưu vào file 'optimal_schedule.xlsx'.

# %%
df_schedule['Room']
# Out:
# 0    A1.01A
# 1     A1.03
# 2     A2.02
# 3     A1.03
# 4     A2.01
# 5     A1.04
# 6     A1.05
# 7     A2.02
# 8     A2.04
# 9     A1.05
# Name: Room, dtype: object

# %%
index=[f"Period {i}" for i in range(1, NUM_PERIODS + 1)]
index
# Out:
# ['Period 1', 'Period 2', 'Period 3', 'Period 4', 'Period 5']

# %%
columns=[f"Day {i}" for i in range(2, 8)]
columns
# Out:
# ['Day 2', 'Day 3', 'Day 4', 'Day 5', 'Day 6', 'Day 7']

# %%
timetable = pd.DataFrame(index=[f"Period {i}" for i in range(1, NUM_PERIODS + 1)],
                             columns=[f"Day {i}" for i in range(2, 8)])
timetable
# Out:
#          Day 2 Day 3 Day 4 Day 5 Day 6 Day 7
# Period 1   NaN   NaN   NaN   NaN   NaN   NaN
# Period 2   NaN   NaN   NaN   NaN   NaN   NaN
# Period 3   NaN   NaN   NaN   NaN   NaN   NaN
# Period 4   NaN   NaN   NaN   NaN   NaN   NaN
# Period 5   NaN   NaN   NaN   NaN   NaN   NaN

# %%
for room in df_schedule['Room'].unique():
    print(room)
# Out:
# A1.01A
# A1.03
# A2.02
# A2.01
# A1.04
# A1.05
# A2.04

# %%
for room in df_schedule['Room'].unique():
    room_schedule = df_schedule[df_schedule['Room'] == room]
    for _, row in room_schedule.iterrows():
        print(row)
# Out:
# Week                       1
# Day                        2
# Period                     1
# Room                  A1.01A
# Subject    Hệ thống Máy tính
# Teacher      Nguyễn Hữu Tình
# Name: 0, dtype: object
# Week                           1
# Day                            2
# Period                         3
# Room                       A1.03
# Subject    Kỹ năng làm việc nhóm
# Teacher          Nguyễn Chí Kiên
# Name: 1, dtype: object
# Week                                      1
# Day                                       2
# Period                                    5
# Room                                  A1.03
# Subject    Giáo dục Quốc phòng và An Ninh 1
# Teacher                    Huỳnh Trung Hiếu
# Name: 3, dtype: object
# Week                        1
# Day                         2
# Period                      3
# Room                    A2.02
# Subject    Nhập môn Lập trình
# Teacher        Bùi Thanh Hùng
# Name: 2, dtype: object
# Week                    1
# Day                     8
# Period                  1
# Room                A2.02
# Subject    Toán cao cấp 1
# Teacher     Lê Trọng Ngọc
# Name: 7, dtype: object
# Week                           1
# Day                            2
# Period                         5
# Room                       A2.01
# Subject    Nhập môn Lập trình_TH
# Teacher           Bùi Thanh Hùng
# Name: 4, dtype: object
# Week                           1
# Day                            4
# Period                         2
# Room                       A1.04
# Subject    Kỹ thuật lập trình_TH
# Teacher           Bùi Thanh Hùng
# Name: 5, dtype: object
# Week                        1
# Day                         8
# Period                      1
# Room                    A1.05
# Subject    Kỹ thuật lập trình
# Teacher        Bùi Thanh Hùng
# Name: 6, dtype: object
# Week                    1
# Day                     8
# Period                  2
# Room                A1.05
# Subject    Toán cao cấp 1
# Teacher     Lê Trọng Ngọc
# Name: 9, dtype: object
# Week                          1
# Day                           8
# Period                        1
# Room                      A2.04
# Subject    Hệ thống Máy tính_TH
# Teacher         Nguyễn Hữu Tình
# Name: 8, dtype: object

# %%
for room in df_schedule['Room'].unique():
    room_schedule = df_schedule[df_schedule['Room'] == room]
    for _, row in room_schedule.iterrows():
        print(f"Period {row['Period']}")
        print(f"Day {row['Day']}")
        print(f"{row['Subject']} ({row['Teacher']})")
# Out:
# Period 1
# Day 2
# Hệ thống Máy tính (Nguyễn Hữu Tình)
# Period 3
# Day 2
# Kỹ năng làm việc nhóm (Nguyễn Chí Kiên)
# Period 5
# Day 2
# Giáo dục Quốc phòng và An Ninh 1 (Huỳnh Trung Hiếu)
# Period 3
# Day 2
# Nhập môn Lập trình (Bùi Thanh Hùng)
# Period 1
# Day 8
# Toán cao cấp 1 (Lê Trọng Ngọc)
# Period 5
# Day 2
# Nhập môn Lập trình_TH (Bùi Thanh Hùng)
# Period 2
# Day 4
# Kỹ thuật lập trình_TH (Bùi Thanh Hùng)
# Period 1
# Day 8
# Kỹ thuật lập trình (Bùi Thanh Hùng)
# Period 2
# Day 8
# Toán cao cấp 1 (Lê Trọng Ngọc)
# Period 1
# Day 8
# Hệ thống Máy tính_TH (Nguyễn Hữu Tình)

# %%
import os

# Tạo thư mục 'images' nếu chưa tồn tại
output_dir = "images"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

for room in df_schedule['Room'].unique():
    room_schedule = df_schedule[df_schedule['Room'] == room]
    timetable = pd.DataFrame(
        index=[f"Period {i}" for i in range(1, NUM_PERIODS + 1)],
        columns=[f"Day {i}" for i in range(2, 8)]  # Thứ 2 đến Chủ nhật
    )

    for _, row in room_schedule.iterrows():
        period = f"Period {row['Period']}"
        day = f"Day {row['Day']}"
        info = f"{row['Subject']} ({row['Teacher']})"
        timetable.loc[period, day] = info

    timetable.fillna("", inplace=True)

    fig, ax = plt.subplots(figsize=(40, 24))
    ax.axis('tight')
    ax.axis('off')
    table = ax.table(
        cellText=timetable.values, 
        colLabels=timetable.columns,
        rowLabels=timetable.index, 
        cellLoc='center', 
        loc='center'
    )
    table.set_fontsize(10)
    table.scale(1, 1)

    plt.title(f"Thời khóa biểu cho phòng: {room}", fontsize=20)

    # Lưu hình ảnh vào thư mục 'images'
    output_file = os.path.join(output_dir, f"{room}_schedule_fixed_v2.png")
    plt.savefig(output_file)
    plt.close()

print("Các bảng thời khóa biểu đã được điều chỉnh và lưu vào thư mục 'images'.")
# Out:
# Các bảng thời khóa biểu đã được điều chỉnh và lưu vào thư mục 'images'.
